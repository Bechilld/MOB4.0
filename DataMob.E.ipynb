# %% [markdown]
# <a href="https://colab.research.google.com/github/Bechilld/MOB4.0/blob/main/DataMob.E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #O que buscar nesse notebook?

# %% [markdown]
# **Os dados nos movem**, nos indica possibilidades, os dados estão cada vez mais importantes. Sabendo disso, aqui, nesse notebook, está **o caminho para aprender a interpretar e usar esses dados**.

# %% [markdown]
# #Por que mobilidade?

# %% [markdown]
# A mobilidade é uma realidade, não tem como viver em sociedade sem pensar na mobilidade. Para essa realidade, aí que entra a Mob4.0, pode ser retirado o melhor que ela tem a oferecer.

# %% [markdown]
# Sempre existe **possibilidades**, **caminhos**, mobilidade é fundamental para **escolher qual seguir**.

# %% [markdown]
# *  A Mob4.0 aponta os problemas e soluções para mobilidade.
# *  A Mob4.0 prove a facilidade na interpretação da mobilidade.

# %% [markdown]
# #Por que fazer parte da Mob4.0?

# %% [markdown]
# A Mob4.0 é um projeto que busca uma cidade inteligente. É de suma importância dentro da complexidade de uma cidade, explorar e facilitar suas engranagens.

# %% [markdown]
# # Aqui entra você, leitor, quer aprender com a Mob4.0?

# %% [markdown]
# A diante, está o caminho para aprender, aprender desde criar um notebook (como esse que o leitor está lendo), até a construção de projetos mais complexos.

# %% [markdown]
# Os conteúdos estão seguindo em módulos curtos, esses com parte escrita e vídeo's.

# %% [markdown]
# #**MÓDULO 1 - O "Mob-Ambiente".**

# %% [markdown]
# Para a primeira etápa, acessar o link ou arquivo, a seguir.

# %% [markdown]
# Acessar: [**Mó(b) 1.**](https://colab.research.google.com/drive/1HjN2dzQt00i8Zw0PUhkfHV4oe4dLykva?usp=sharing)

# %% [markdown]
# #**MÓDULO 2 - Primeira demonstração**.

# %% [markdown]
# O que o ambiente já instalado pode fazer?

# %% [markdown]
# Acessar: [**Mó(b) 2.**](https://colab.research.google.com/drive/1M8YQmlIsNGf_fKLePFiY-l9D_-rE4Ch4?usp=sharing)

# %% [markdown]
# #**MÓDULO 3 - Coletando dados importantes.**

# %% [markdown]
# Como extrair um dado especifico de "infinitos" dados? Como trabalhar uma coluna em especifica?

# %% [markdown]
# Acessar: [**Mó(b) 3.**](https://colab.research.google.com/drive/1wi0oD10zucwrXdL1lRAB4JeY70JbiRsy?usp=sharing)

# %% [markdown]
# #**MÓDULO 4 - PIP.**

# %% [markdown]
# Peguei um projeto, como sei que as intalações já feitas na minha máquina são suficientes?

# %% [markdown]
# Acessar: [**Mó(b) 4.**](https://colab.research.google.com/drive/1Qzhn5EtBR9d_wlhDIWhFHZyreflInBGh?usp=sharing)
